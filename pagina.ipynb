# %% [markdown]
# - Anomizar datos (más alla de los nombres) ¿que pasa con la gente que no ha terminado el doctorado?
# - Considerar los límites de los datos (trayectorias y construcción de perfil)
#
# - Replicación del proyecto
# - Equipo
# - Intervenciones
# - Reproductibilidad de los datos
#
# ¿que datos son necesarios?
#
# ¿Qué vamos a anominizar?
#
# (clasificar en termino de categorías)
#
# Que puede producir?
# Que puede apoyar?

# %%
To DO: topics -> maestra (segmentar)
- Que hay del abstract (correo) con la investigación : encontrar vinculos asociaciones o cualquier relacíon.
