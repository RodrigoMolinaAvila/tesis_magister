# %% [markdown]
# ## Índice propuesto de la tesis
#
# **Portada, Resumen y Abstract**
# 1.1. Agradecimientos
# 1.2. Lista de figuras y tablas
#
# **Introducción**
# 2.1. Justificación del estudio y aporte esperado
# 2.2. Contexto: educación superior chilena, STEM y Ciencias Sociales
# 2.3. Problema de investigación y preguntas orientadoras
# 2.4. Objetivo general y objetivos específicos
# 2.5. Originalidad: grafos de conocimiento + modelamiento temático automatizado
# 2.6. Estructura del documento
#
# **Antecedentes**
# 3.1. Desigualdades estructurales en educación superior (Chile y comparados)
# 3.2. Modelo androcéntrico y sesgos en STEM; dependencia epistémica en Ciencias Sociales
# 3.3. Evidencia nacional sobre estratificación por clase/género y expansión doctoral
# 3.4. Relevancia de grafos de conocimiento para trayectorias académicas
#
# **Marco Teórico**
# **Bloque A. Desigualdades e interseccionalidad en trayectorias académicas**
# 4.1. Interseccionalidad como teoría de estratificación (género/clase/otras)
# 4.2. Reproducción social y capitales (económico, social, cultural) en la academia
# 4.3. Redes, prestigio institucional y mecanismos de cierre social en contratación académica
# 4.4. Evidencia para el caso chileno: expansión doctoral, estratificación y empleo académico
# **Bloque B. Textos científicos como huella de prácticas y campos**
# 4.5. Publicaciones y resúmenes como señales de campo, subcampo y agencia
# 4.6. Sesgos y asimetrías en producción y circulación del conocimiento
#
# **Estado del Arte Metodológico**
# 5.1. NLP en corpus académicos: representaciones semánticas multilingües
# 5.2. Descubrimiento de tópicos: LDA vs. enfoques con sentence embeddings
# 5.3. BERTopic: UMAP + HDBSCAN + representación de tópicos
# 5.4. Modelos NLI para alineamiento semántico entre descripciones
# 5.5. Grafos de conocimiento: conceptos, ontologías y casos en educación superior
#
# **Datos y Fuentes**
# 6.1. Población de estudio: becarios/as BECAS CHILE & CONICYT (cohorte 2014–2016)
# 6.2. Fuentes: Portal de Transparencia, Mineduc, Scopus API, CNA, rankings y scraping
# 6.3. Variables sociodemográficas, institucionales y bibliométricas
# 6.4. Criterios éticos, resguardo y licenciamiento de datos
#
# **Metodología (visión general)**
# 7.1. Diseño: estudio cuantitativo de tipo exploratorio-explicativo
# 7.2. Flujo general: consolidación de datos → modelamiento temático → mapeo categorías → asignación tópico–autor → construcción de grafo de conocimiento
# 7.3. Validación, reproducibilidad y pipeline computacional
#
# **Modelamiento Temático con Transfer Learning**
# 8.1. Preprocesamiento y normalización de textos (título, keywords, abstract)
# 8.2. Embeddings multilingües (Sentence-BERT): 𝑒𝑖∈𝑅𝑑
# 8.3. UMAP (reducción a 𝑅10): preservación de estructura vecinal
# 8.4. HDBSCAN: densidad, prediction_data y detección de ruido
# 8.5. BERTopic: extracción de palabras clave y probabilidades por tópico
# 8.6. Reasignación de ruido en dos fases
# - Fase A: approximate_predict (HDBSCAN) con umbral de fuerza
# - Fase B: coseno a centroides de tópicos; aceptación si cos(𝑒𝑖,𝑡ˉ𝑘)≥𝜏
# 8.7. Asignación de tópico principal por documento (Top–1) y multietiqueta (umbral 𝜏)
#
# **Mapeo de Tópicos a Categorías Disciplinarias**
# 9.1. Prototipos por categoría: 𝑐ˉ𝑗=1∣𝑆𝑗∣∑𝑖∈𝑆𝑗𝑒𝑖
# 9.2. Representación de tópicos vía k mejores documentos
# 9.3. Matrices de similitud:
# - Coseno 𝑆𝑘,𝑗cos=cos(𝑡ˉ𝑘,𝑐ˉ𝑗)
# - NLI 𝑆𝑘,𝑗nli=𝑝(entailment∣𝑑𝑘,𝑐𝑗)
# - Fusión: 𝑆=𝛼 𝑆cos+(1−𝛼) 𝑆nli
# 9.4. Sintonización con Optuna: búsqueda de 𝛼,𝜏,𝑘top
# 9.5. Métricas a nivel documento: macro-F1, micro-F1 y hit-rate multietiqueta
# 9.6. Visualizaciones: heatmaps (coseno/NLI/fusión), UMAP 2D y confusión
#
# **Asignación de Tópico a Autor y Construcción del Grafo**
# 10.1. Regla de asignación autor–tópico (vía agregación sobre sus documentos):
# - Tópico principal por autor 𝑡^𝑎=argmax𝑘∑𝑖∈𝐷(𝑎)1[𝑡𝑖=𝑘]
# - Distribución temática del autor 𝑝𝑎(𝑘)∝∑𝑖∈𝐷(𝑎)Pr(𝑡=𝑘∣𝑖)
# 10.2. Esquema de grafo de conocimiento (ontología mínima):
# - Nodos: Autor, Institución, Publicación, Tópico, Categoría
# - Aristas: (Autor)–[ESCRIBE]→(Publicación), (Publicación)–[PERTENECE_A]→(Tópico), (Tópico)–[MAPEA_A]→(Categoría), (Autor)–[AFILIADO_A]→(Institución), etc.
# 10.3. Propiedades de nodos y aristas (género, proxies de clase, ranking, años, métricas)
# 10.4. Exportación e ingesta en Neo4j (placeholders de Cypher y CSV)
# 10.5. Chequeos de calidad del grafo: unicidad, conectividad y consistencia temporal
#
# **Análisis Estructural del Grafo (placeholders para resultados)**
# 11.1. Componentes y conectividad; métricas globales
# 11.2. Centralidades (degree/closeness/betweenness/eigenvector)
# 11.3. Comunidades (Leiden) y segmentación temática por género/clase
# 11.4. Caminos y trayectorias: movilidad institucional y gatekeepers
# 11.5. Subredes STEM vs. Ciencias Sociales y mixing patterns
#
# **Resultados (placeholders)**
# 12.1. Cohorte y corpus: descriptivos
# 12.2. Tópicos y categorías: calidad, ejemplos y cobertura
# 12.3. Autor–tópico–institución: patrones diferenciales por género/clase
# 12.4. Sensibilidades: variaciones de 𝛼,𝜏,𝑘top y UMAP/HDBSCAN
# 12.5. Hallazgos clave para las preguntas de investigación
#
# **Discusión (placeholders)**
# 13.1. Interpretación teórica desde el enfoque interseccional
# 13.2. Reproducción de desigualdades y cierre social en el campo académico
# 13.3. Implicancias de política pública y gestión universitaria
#
# **Conclusiones (placeholders)**
# 14.1. Respuestas a los objetivos
# 14.2. Contribuciones metodológicas (BERTopic+NLI+Optuna → KG)
# 14.3. Limitaciones y amenazas a la validez
# 14.4. Trabajo futuro (enriquecimiento ontológico, desambiguación de autores, temporal KG)
#
# **Reproducibilidad y Paquete Computacional**
# 15.1. Estructura de repositorio y pipelines
# 15.2. Versionado de datos y model cards
# 15.3. Consideraciones de fairness y data governance
#
# **Referencias**
#
# **Anexos**
# A. Manual de normalización U. de Chile (cumplimiento de formato)
# B. Diccionario de variables y data provenance
# C. Tablas complementarias (hiperparámetros, ablation studies)
# D. Guías de ingestión a Neo4j (Cypher y esquemas)
# E. Capturas de dashboards/EDA
#
# ---

# %% [markdown]
# Introducción y Antecedentes
#
# 2.2 Contexto: educación superior chilena, STEM y CCSS
#
# Fleet, N. (2024). Regional inequalities among state universities in Chile. Higher Education Quarterly. — Para caracterizar desigualdades territoriales, centralismo y efectos de mercado en el sistema chileno.
# ERIC
#
# Quaresma, M. L. (2022). Elite universities in Chile: Between social mobility and stratification. Tuning Journal. — Discute dualización del sistema y selección socioeconómica; útil para situar “campo” y mecanismos de cierre.
# Tuning Journal
#
# 3.1 Desigualdades estructurales (Chile y comparados)
#
# Brunner/ANID/DIPRES (2017). Informe final de evaluación programa Becas Chile y nacionales. — Documento estatal para serie histórica y teoría de cambio del instrumento.
# Dipres
#
# SEGIB (2021). Educación Superior en Iberoamérica 2000–2020. — Base comparada de masificación regional.
# Secretaría General Iberoamericana
#
# 3.2 Modelo androcéntrico y sesgos en STEM; dependencia epistémica
#
# Moss-Racusin, C. A., et al. (2012). Science faculty’s subtle gender biases favor male students. PNAS. — Evidencia experimental de sesgo en evaluaciones/contratación; enmarca “modelo androcéntrico”.
# PNAS
# +1
#
# UNESCO (2017). Cracking the Code: Girls’ and Women’s Education in STEM. — Panorama global, cifras y factores de segregación horizontal.
# unesdoc.unesco.org
# +1
#
# Beigel, F. (2014+) y literatura sobre “circulación del conocimiento” — Para dependencia/jerarquías centro-periferia en CCSS. Usa síntesis reciente.
# global-qualitative-sociology.net
# +1
#
# 3.3 Evidencia nacional: estratificación por clase/género y expansión doctoral
#
# Labraña, J. (2021). Economía del conocimiento y formación de doctores/as en Chile. — Serie y tasas de graduación doctorales; insumo para tendencias 2008–2019.
# Redalyc
# +1
#
# ANID (2025). Becas Chile: estado y cumplimiento de obligaciones y retribución. BCN. — Cifras 2014–2024 y reglas de retorno.
# Biblioteca Congreso Chile
#
# CONICYT/ANID (bases y llamados). — Especificaciones de cohortes 2014–2016 del instrumento BCH-Doctorado Exterior.
# conicyt.cl
# +1
#
# 3.4 Relevancia de grafos de conocimiento para trayectorias académicas
#
# Priem, J., Piwowar, H., & Orr, R. (2022). OpenAlex. — Justifica el uso de KGs bibliográficos abiertos para modelar autores, obras, instituciones y conceptos.
# arXiv
# +1
#
# Färber, M. (2019/2022). Microsoft Academic Knowledge Graph (MAKG). — Ejemplo de KG académico a escala con ontología y tripletas; base para tu esquema.
# dl.acm.org
# +1
#
# Marco Teórico
#
# Bloque A — 4.1 Interseccionalidad (género/clase/otras)
#
# Collins, P. H. (2019). Intersectionality as Critical Social Theory. — (ya en tu biblio) para anclar la arquitectura conceptual.
#
# 4.2 Reproducción social y capitales
#
# Canales, A. (2016). La reproducción de la élite en Chile. — (ya en tu biblio) ancla local de habitus/capital cultural y circuitos de élite.
#
# 4.3 Redes, prestigio y cierre social en contratación académica
#
# Clauset, A., et al. (2015). Systematic inequality and hierarchy in faculty hiring networks. Science Advances. — Evidencia dura de jerarquías y “prestige closure”. Úsalo para formalizar mecanismos de estratificación vía redes.
# Science
# +2
# stat.cmu.edu
# +2
#
# Wapman, K. H., et al. (2022). Quantifying hierarchy and dynamics in US faculty hiring networks. Nature. — Actualiza con dinámica y cierre social persistente.
# Nature
#
# 4.4 Evidencia chilena: expansión doctoral/empleo académico
#
# Labraña (2021) de nuevo para cifras; complementa con documentos CNA sobre acreditación doctoral como marco regulatorio.
# cnachile.cl
#
# Bloque B — 4.5 Textos científicos como señales de campo
#
# OpenAlex/MAKG (arriba) para operacionalizar “campo/subcampo” mediante metadatos y co-citas.
# arXiv
# +1
#
# 4.6 Sesgos y asimetrías en producción/circulación
#
# Moss-Racusin (2012) + UNESCO (2017) como base empírica + decolonialidad/epistemic injustice en HE chilena (Guzmán-Valenzuela et al., 2022; ya en tu biblio).
# PNAS
# +1
#
# Estado del Arte Metodológico
#
# 5.1 NLP en corpus académicos: representaciones semánticas multilingües
#
# Reimers & Gurevych (2019). Sentence-BERT (SBERT). — Base para embeddings semánticos sentenciales.
# arXiv
# +1
#
# Feng et al. (2020/2022). LaBSE. — Embeddings multilingües para alineamiento español-inglés (clave en tu corpus).
# arXiv
# +1
#
# LASER (Artetxe & Schwenk, 2019). — Alternativa multilingüe y comparador.
# arXiv
# +1
#
# 5.2 Descubrimiento de tópicos: LDA vs. embeddings
#
# Egger, R. & Yu, H. (2022). A Topic Modeling Comparison Between LDA, NMF, Top2Vec, BERTopic. — Revisión comparativa con métricas de coherencia.
# PMC
#
# 5.3 BERTopic (UMAP + HDBSCAN + c-TF-IDF)
#
# Grootendorst, M. (2022). BERTopic: Neural topic modeling… — Referencia canónica del pipeline y c-TF-IDF.
# arXiv
# +1
#
# 5.4 Modelos NLI para alineamiento semántico
#
# Williams et al. (2018). MultiNLI. — Dataset base para NLI.
# aclanthology.org
#
# Conneau et al. (2018). XNLI. — Estándar de evaluación multilingüe para NLI (justifica transferencia a español).
# aclanthology.org
# +1
#
# Liu et al. (2019). RoBERTa. — Backbones SOTA para NLI/entailment.
# arXiv
# +1
#
# 5.5 Grafos de conocimiento
#
# Hogan, A., et al. (2021). Knowledge Graphs. ACM Computing Surveys. — (ya en tu biblio) síntesis del stack KG.
#
# MAKG y OpenAlex (arriba) como casos aplicados académicos.
# dl.acm.org
# +1
#
# Datos y Fuentes
#
# 6.1–6.2 Becas Chile/CONICYT (cohorte 2014–2016)
#
# Sitios oficiales de llamados BCH 2016 + ANID “Becas en el Extranjero”. — Para criterios de elegibilidad y ventanas temporales.
# conicyt.cl
# +1
#
# BCN (2025) informe sobre cumplimiento/retorno. — Para cuantificar obligaciones y tasas.
# Biblioteca Congreso Chile
#
# 6.3–6.4 Ética, licenciamiento y acreditación
#
# CNA Chile: Criterios y estándares de acreditación de doctorado (PDF). — Cita normativa vigente; cruza con tu variable “programa acreditado/no acreditado”.
# cnachile.cl
#
# Metodología y Modelamiento
#
# 7.2 Flujo general / 8.x Pipeline BERTopic
#
# UMAP: McInnes et al. (2018) — Fundamento topológico de la reducción (manifold + simplicial sets).
# arXiv
# +1
#
# HDBSCAN: Campello et al. (2013) + doc de librería hdbscan con prediction_data/approximate_predict. — Para tu 8.4 y 8.6 (reasignación de ruido).
# SpringerLink
# +2
# hdbscan
# +2
#
# SBERT/LaBSE (arriba) para 8.2 embeddings multilingües.
# arXiv
# +1
#
# 8.6 Reasignación de ruido en dos fases
#
# Doc hdbscan (tutorial + FAQ), issues y notas técnicas sobre approximate_predict (edge cases, NaN). — Justifica umbrales y fallback por coseno a centroides.
# hdbscan
# +2
# hdbscan
# +2
#
# 8.7 Asignación Top-1 y multietiqueta (τ)
#
# Egger (2022) para criterios de coherencia/covertura vs. ruido.
# PMC
#
# Mapeo de Tópicos a Categorías (NLI + Coseno)
#
# 9.1–9.4 Prototipos, similitudes y fusión
#
# XNLI/MultiNLI + RoBERTa como modelos y datos base para p(entailment | d_k, c_j).
# aclanthology.org
# +2
# aclanthology.org
# +2
#
# Optuna (Akiba et al., 2019) para sintonía de α, τ, k_top. — Justifica define-by-run y pruning.
# arXiv
# +1
#
# 9.5–9.6 Métricas y visualizaciones
#
# Estándares macro/micro-F1 multi-label (no cita específica requerida). Para comunidades/heatmaps, referir UMAP/Leiden abajo.
#
# Asignación de Tópico a Autor y Grafo
#
# 10.2 Ontología mínima y KG académico
#
# OpenAlex/MAKG para tipologías de nodos/aristas y propiedades (IDs persistentes).
# arXiv
# +1
#
# 10.5 Calidad del grafo
#
# Prácticas de unicidad y consistencia temporal: ver documentación de OpenAlex (IDs/merged-entities).
# docs.openalex.org
#
# Análisis Estructural del Grafo
#
# 11.1–11.2 Métricas globales/centralidades
#
# Freeman (1977/1978) — betweenness y clarificación conceptual de centralidad.
# JSTOR
# +1
#
# Bonacich (1987) — eigenvector/power centrality.
# cse.cuhk.edu.hk
# +1
#
# Page et al. (1999) — PageRank para publicaciones/instituciones.
# ilpubs.stanford.edu
# +1
#
# 11.3 Comunidades
#
# Traag, Waltman & Van Eck (2019). Leiden algorithm — Garantías de conectividad y particiones superiores a Louvain.
# arXiv
# +1
#
# 11.5 Mixing patterns (STEM vs. CCSS, género/clase)
#
# Newman (2002/2003). Assortative mixing. — Métricas de homofilia por atributo y por grado.
# arXiv
# +1
#
# Resultados / Discusión (apoyos para futuras citas)
#
# 12.3/13.2 Patrones diferenciales por género/clase
#
# Moss-Racusin (2012) como contraste empírico; UNESCO/CILAC (2022) para LAC.
# PNAS
# +1
#
# 13.3 Implicancias de política pública
#
# CNA (criterios doctorado) para vínculos normativos sobre calidad y empleabilidad.
# cnachile.cl
#
# Reproducibilidad y Paquete Computacional
#
# 15.3 Fairness y data governance
#
# Documentación OpenAlex (citas y best practices de uso/atribución de datos).
# docs.openalex.org
